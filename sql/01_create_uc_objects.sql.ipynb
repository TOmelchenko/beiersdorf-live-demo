# %%
# %sql
CREATE CATALOG IF NOT EXISTS beiersdorf_dev;
CREATE SCHEMA IF NOT EXISTS beiersdorf_dev.reporting;
CREATE VOLUME IF NOT EXISTS beiersdorf_dev.reporting.landing;
CREATE VOLUME IF NOT EXISTS beiersdorf_dev.reporting.checkpoints;
